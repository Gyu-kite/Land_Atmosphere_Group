# %% [markdown]
# # Module

# %%
import numpy as np
import xarray as xr
import pandas as pd
from netCDF4 import Dataset, MFDataset
import netCDF4
import matplotlib.pyplot as plt
import glob
from datetime import datetime, timedelta
from scipy import stats
import shutil
from scipy.spatial import distance
import metpy
import xskillscore as xs
import matplotlib.ticker as mticker
import cartopy.feature as cfeature
import cartopy.crs as ccrs
import cartopy.mpl.ticker as cticker
from cartopy.util import add_cyclic_point
from cartopy.feature import NaturalEarthFeature
from glob import *
import sys, os, time, warnings
import pandas as pd
import pytz
from cartopy.mpl.gridliner import LongitudeFormatter, LatitudeFormatter
warnings.filterwarnings(action='ignore')
warnings.simplefilter(action='ignore')
from dask.diagnostics import ProgressBar
import metpy

# %% [markdown]
# # function
# 아래의 함수들 포함.
#
# fft_1st_phase(a)
# find_nearest(array, value)
# find_nearest_idx(array, value)
# harm_1st_max_idx(array, values)
# diurnal_cycle_fig(data,daily_mean_data,time,data_source)
# grid_transfer(data)
# regrid(change_data,target_data)
# amplitude_fig(data,data_source)amplitude_fig(data,data_source)
# print(f"latitude : {i}", end='\r') # 순서 보여주는거

# %% [markdown]
# ### harmonic analysis function

# %%
def fft_1st_phase(a):
    ff = np.fft.fft(a)
    # Get the complex vector at that frequency to retrieve amplitude and phase shift
    yy = ff[1] 

    # Calculate the amplitude
    T = a.shape[0] # domain of x; which we will divide height to get freq amplitude
    A = np.sqrt(yy.real**2 + yy.imag**2)/T 
    # print('amplitude of:', A) 
    
    # Calculate phase shift
    phi = np.arctan(yy.imag/yy.real)
    # print('phase change:', phi)
    
    return phi, yy.real ,A


def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return array[idx]

def find_nearest_idx(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

def harm_1st_max_idx(array, values): # 앞에가 시간 뒤에가 강수
    pp=0
    if fft_1st_phase(values)[1]>0:
        if fft_1st_phase(values)[0]<0:
            pp = -fft_1st_phase(values)[0]/np.pi *np.pi
        elif fft_1st_phase(values)[0]>0:
            pp = ( 2. - fft_1st_phase(values)[0]/np.pi ) *np.pi
    elif fft_1st_phase(values)[1]<0:
        pp = ( -fft_1st_phase(values)[0]/np.pi + 1. ) *np.pi    
    
    pp2 = np.nanmax(array,axis=0) * pp / (2.*np.pi)    
    return find_nearest_idx(array, pp2)

# %% [markdown]
# ### diurnal cycle fig function

# %%
def diurnal_cycle_fig(data,daily_mean_data,time,data_source):

    if time == 'utc':
        tt = 'UTC(hour)'
    else : 
        tt = 'LST(hour)'
        
    tick_spacing = 30

    projection = ccrs.PlateCarree()
    crs = ccrs.PlateCarree()
    fig = plt.figure(figsize=(20,10))
    ax = plt.axes(projection=projection, frameon=True)


    varMin, varMax, varInt = 0, 24, 1
    levels = np.arange(varMin, varMax+varInt, varInt)
    nlevs  = levels.size
    tick_interval = 2
    cmap = plt.get_cmap('Spectral', nlevs)
    extent=[-180, 180, -60, 60]
    gl = ax.gridlines(crs=crs, draw_labels=True, linewidth=1, color='gray', alpha=1, linestyle='-.')
    gl.xlabel_style = {"size" : 13}
    gl.ylabel_style = {"size" : 13}
    gl.xlocator = mticker.FixedLocator(np.arange(extent[0], extent[1] + tick_spacing, tick_spacing))
    gl.ylocator = mticker.FixedLocator(np.arange(extent[2], extent[3] + tick_spacing, tick_spacing))

    ax.xaxis.set_major_formatter(LongitudeFormatter())
    ax.yaxis.set_major_formatter(LatitudeFormatter()) 

    gl.top_labels = None
    gl.right_labels = None

    ax.add_feature(cfeature.COASTLINE.with_scale("50m"), lw=0.8)
    ax.add_feature(cfeature.OCEAN.with_scale("50m"), edgecolor='none', facecolor='lightgray')
    ax.add_feature(cfeature.BORDERS.with_scale("50m"), lw=0.3)
    ax.set_extent([-180, 180, -60, 60], crs=ccrs.PlateCarree())

    lons = data['longitude']  # 경도
    lats = data['latitude']  # 위도
    values = data[time]

    lons, lats = np.meshgrid(data['longitude'], data['latitude'])

    cnplot = ax.contourf(lons, lats, values,cmap=cmap,levels=levels,zorder=0,transform=ccrs.PlateCarree())

    cbar = plt.colorbar(cnplot,ticks=np.arange(varMin, varMax+tick_interval, tick_interval), 
                        orientation='vertical', pad=0.01, shrink=.575) 

    zm = np.ma.masked_less(daily_mean_data, 0.275)
    plt.pcolor(lons, lats,zm, hatch='xxx', alpha=0.)

    cbar.set_label(tt, fontsize=15)
    cbar.ax.tick_params(labelsize=15)

    plt.xlabel('Longitude',fontsize=10,fontweight='bold')
    plt.ylabel('Latitude',fontsize=10,fontweight='bold')    
    ax.set_title(data_source+' [JJA 2022]',fontsize=20,fontweight='bold')
    plt.show()

# %% [markdown]
# ### grid inverse function

# %%
def grid_transfer(data):
    data=data.sortby(data['latitude'], ascending=True) #위도 ㅂ반전
    data['longitude'] = xr.where(data['longitude'] > 180, data['longitude'] - 360, data['longitude']) # 경도 반전
    data = data.sortby(data['longitude']) #바뀐 경도에 대해 값들 맞춰줌 한번만 실행할것
    
    return data

# %% [markdown]
# ### amplitude_fig

# %%
def amplitude_fig(data,data_source):

    tick_spacing = 30
    projection = ccrs.PlateCarree()
    crs = ccrs.PlateCarree()
    fig = plt.figure(figsize=(20,10))
    ax = plt.axes(projection=projection, frameon=True)


    varMin, varMax, varInt = 0, 2, 0.1
    levels = np.arange(varMin, varMax+varInt, varInt)
    nlevs  = levels.size
    tick_interval = 0.2
    cmap = plt.get_cmap('plasma', nlevs)
    extent=[-180, 180, -60, 60]

    gl = ax.gridlines(crs=crs, draw_labels=True, linewidth=1, color='gray', alpha=1, linestyle='-.')
    gl.xlabel_style = {"size" : 13}
    gl.ylabel_style = {"size" : 13}
    gl.xlocator = mticker.FixedLocator(np.arange(extent[0], extent[1] + tick_spacing, tick_spacing))
    gl.ylocator = mticker.FixedLocator(np.arange(extent[2], extent[3] + tick_spacing, tick_spacing))

    ax.xaxis.set_major_formatter(LongitudeFormatter())
    ax.yaxis.set_major_formatter(LatitudeFormatter()) 

    gl.top_labels = None
    gl.right_labels = None

    ax.add_feature(cfeature.COASTLINE.with_scale("50m"), lw=0.8)
    ax.add_feature(cfeature.OCEAN.with_scale("50m"), edgecolor='none', facecolor='lightgray')
    ax.add_feature(cfeature.BORDERS.with_scale("50m"), lw=0.3)
    ax.set_extent([-180, 180, -60, 60], crs=ccrs.PlateCarree())

    lons = data['longitude']  # 경도
    lats = data['latitude']  # 위도
    values = data['amlitude']

    lons, lats = np.meshgrid(data['longitude'], data['latitude'])

    cnplot = ax.contourf(lons, lats, values,cmap=cmap,levels=levels,zorder=0,
                         transform=ccrs.PlateCarree(),extend='max')

    cbar = plt.colorbar(cnplot,ticks=np.arange(varMin, varMax+tick_interval, tick_interval), 
                        orientation='vertical', pad=0.01, shrink=.56) 

    # zm = np.ma.masked_less(daily_mean_data, 0.275)
    # plt.pcolor(lons, lats,zm, hatch='xxx', alpha=0.)

    cbar.set_label('Amplitude', fontsize=15)
    cbar.ax.tick_params(labelsize=15)

    plt.xlabel('Longitude',fontsize=10,fontweight='bold')
    plt.ylabel('Latitude',fontsize=10,fontweight='bold')    
    ax.set_title(data_source+' [JJA 2022]',fontsize=20,fontweight='bold')
    plt.show()

# %% [markdown]
# ### grid same

# %%
import xesmf as xe

# %%
def regrid(change_data,target_data):
    grid_frame = xe.Regridder(change_data, target_data, "bilinear")
    regrid_data=grid_frame(change_data)
    return regrid_data

# %% [markdown]
# # ERA5 자료 처리

# %% [markdown]
# Mean rate/flux parameters in ERA5 (e.g. Table 4 for surface and single levels) provide similar information to accumulations
# (e.g. Table 3 for surface and single levels), except they are expressed as temporal means, over the same processing periods, and so have units of "per second".
#
# Mean rate/flux parameters are easier to deal with than accumulations because the units do not vary with the processing period.
# The mean rate hydrological parameters (e.g. the "Mean total precipitation rate") have units of "kg m-2 s-1", which are equivalent to "mm s-1".
# They can be multiplied by 86400 seconds (24 hours) to convert to kg m-2 day-1 or mm day-1.

# %% [markdown]
# ## 1979~2022 data save

# %%
ERA5_pre_folder = '/data1/ERA5/hourly/land/'

# %%
landdata = sorted(glob(ERA5_pre_folder+'*6_land.nc')+glob(ERA5_pre_folder+'*7_land.nc')+glob(ERA5_pre_folder+'*8_land.nc'))

# %%
era_base = xr.open_mfdataset(landdata, data_vars=['msshf', 'mslhf', 'mtpr'],
                             chunks={ 'latitude':'auto','longitude':'auto','time': 1})
era_base = era_base[['msshf', 'mslhf', 'mtpr']]

# %%
year = np.arange(1979,2023)

# %%
year = np.arange(1979,2023)
year_data = []

for i in range (len(year)):
    
    year_data.append(era_base.sel(time = (era_base['time.year'] == year[i]),drop = True))
    print(f'year',year[i],end='\r')
# Out:
# year 2022

# %%
for i in range (len(year)):
    mtpr = year_data[i]['mtpr'].resample(time='3H').sum('time')
    year_data[i]= year_data[i].resample(time='3H').mean('time')
    
    
    year_data[i]['mtpr']=mtpr*60*60*3 # 누적 강수로 만들어줌 mm/3h
    year_data[i]['mslhf']=-year_data[i]['mslhf']
    year_data[i]['msshf']=-year_data[i]['msshf']
    year_data[i]['ef'] = year_data[i]['mslhf']/(year_data[i]['mslhf']+year_data[i]['msshf'])
    print(f'year',year[i],end='\r')
# Out:
# year 2022

# %%
year_data[0]
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 736, latitude: 721, longitude: 1440)
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 1979-06-01 ... 1979-08-31T21:00:00
# Data variables:
#     msshf      (time, latitude, longitude) float32 dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     mslhf      (time, latitude, longitude) float32 dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     mtpr       (time, latitude, longitude) float32 dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     ef         (time, latitude, longitude) float32 dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2020-11-12 09:46:32 GMT by grib_to_netcdf-2.16.0: /opt/ecmw...

# %%
for i in range (len(year)):
    with ProgressBar():
        str
        year_data[i].to_netcdf('/data1/user/gychoi/Data/ERA_land/ERA_lst_base'+str(year[i])+'.nc')
        print(f'Year =',year[i],end='\r')
# Out:
# [########################################] | 100% Completed | 56.62 s
# [########################################] | 100% Completed | 56.93 s
# [########################################] | 100% Completed | 57.33 s
# [########################################] | 100% Completed | 60.48 s
# [########################################] | 100% Completed | 51.96 s
# [########################################] | 100% Completed | 61.15 s
# [########################################] | 100% Completed | 59.89 s
# [########################################] | 100% Completed | 57.20 s
# [########################################] | 100% Completed | 62.70 s
# [########################################] | 100% Completed | 60.33 s
# [########################################] | 100% Completed | 57.75 s
# [########################################] | 100% Completed | 58.74 s
# [########################################] | 100% Completed | 61.03 s
# [########################################] | 100% Completed | 57.86 s
# [########################################] | 100% Completed | 60.30 s
# [########################################] | 100% Completed | 58.53 s
# [########################################] | 100% Completed | 64.08 s
# [########################################] | 100% Completed | 69.01 s
# [########################################] | 100% Completed | 60.50 s
# [########################################] | 100% Completed | 68.80 s
# [########################################] | 100% Completed | 61.84 s
# [########################################] | 100% Completed | 65.95 s
# [########################################] | 100% Completed | 60.74 s
# [########################################] | 100% Completed | 56.18 s
# [########################################] | 100% Completed | 60.91 s
# [########################################] | 100% Completed | 68.15 s
# [########################################] | 100% Completed | 61.54 s
# [########################################] | 100% Completed | 60.83 s
# [########################################] | 100% Completed | 62.24 s
# [########################################] | 100% Completed | 65.46 s
# [########################################] | 100% Completed | 65.73 s
# [########################################] | 100% Completed | 61.16 s
# [########################################] | 100% Completed | 65.73 s
# [########################################] | 100% Completed | 60.54 s
# [########################################] | 100% Completed | 64.94 s
# [########################################] | 100% Completed | 65.76 s
# [########################################] | 100% Completed | 59.51 s
# [########################################] | 100% Completed | 57.32 s
# [########################################] | 100% Completed | 64.71 s
# [########################################] | 100% Completed | 67.42 s
# [########################################] | 100% Completed | 64.31 s
# [########################################] | 100% Completed | 59.20 s
# [########################################] | 100% Completed | 70.45 s
# [########################################] | 100% Completed | 69.09 s
# Year = 2022

# %% [markdown]
# ## Make lst data

# %%
year = np.arange(1979,2023)
hour = np.arange(0,24,3)

# %%
file_list=sorted(glob('/data1/user/gychoi/Data/ERA_land/ERA_lst_base' + '*.nc'))

# %%
file_list
# Out:
# ['/data1/user/gychoi/Data/ERA_land/ERA_lst_base1979.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1980.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1981.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1982.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1983.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1984.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1985.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1986.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1987.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1988.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1989.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1990.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1991.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1992.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1993.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1994.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1995.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1996.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1997.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1998.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base1999.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2000.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2001.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2002.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2003.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2004.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2005.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2006.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2007.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2008.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2009.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2010.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2011.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2012.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2013.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2014.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2015.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2016.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2017.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2018.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2019.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2020.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2021.nc',
#  '/data1/user/gychoi/Data/ERA_land/ERA_lst_base2022.nc']

# %%
year[10]
# Out:
# 1989

# %%
hour = np.arange(0,24,3)
file = []

for i in range (len(year[0:10])):
    file = []
    data=xr.open_dataset(file_list[0:10][i])

    for j in range (len(hour)):
        hourly = data.sel(time = data['time.hour']==hour[j]).resample(time='D').mean('time')
        file.append(hourly.sel(time=(( hourly['time.month'] >= 6) & ( hourly['time.month'] <= 8)),drop=True))

        print(f'hour =',hour[j],end='\r')

    file = xr.concat(file,'hour')
    file['hour'] = hour
    file.to_netcdf('/data1/user/gychoi/Data/ERA_land/LST/ERA_lst'+str(year[i])+'.nc')

    del(file)
    data.close()

    print(f'year =',year[0:10][i],end='\r')
# Out:
# year = 1988

# %%
hour = np.arange(0,24,3)
file = [0 for i in range (len(year[0:10]))]
concat = [[0 for i in range(len(hour))] for i in range (len(year[0:10]))]

for i in range (len(year[0:10])):
    file[i]=xr.open_dataset(file_list[0:10][i])
    
    for j in range (len(hour)):
        hourly = file[i].sel(time = file[i]['time.hour']==hour[i]).resample(time='D').mean('time')
        concat[i][j] = hourly.sel(time=(( hourly['time.month'] >= 6) & ( hourly['time.month'] <= 8)),drop=True)
        
        print(f'hour =',hour[j],end='\r')
        
    print(f'year =',year[0:10][i],end='\r')
# Out:
# hour = 1880
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 9
#       6 file[i]=xr.open_dataset(file_list[0:10][i])
#       8 for j in range (len(hour)):
# ----> 9     hourly = file[i].sel(time = file[i]['time.hour']==hour[i]).resample(time='D').mean('time')
#      10     concat[i][j] = hourly.sel(time=(( hourly['time.month'] >= 6) & ( hourly['time.month'] <= 8)),drop=True)
#      12     print(f'hour =',hour[j],end='\r')
#
# File ~/anaconda3/envs/kite/lib/python3.9/site-packages/xarray/core/_aggregations.py:4332, in DatasetResampleAggregations.mean(self, dim, skipna, keep_attrs, **kwargs)
#    4322     return self._flox_reduce(
#    4323         func="mean",
#    4324         dim=dim,
#    (...)
#    4329         **kwargs,
#    4330     )
#    4331 else:
# -> 4332     return self.reduce(
#    4333         duck_array_ops.mean,
#    4334         dim=dim,
#    4335         skipna=skipna,
#    4336         numeric_only=True,
#    4337         keep_attrs=keep_attrs,
#    4338         **kwargs,
#    4339     )
#
# File ~/anaconda3/envs/kite/lib/python3.9/site-packages/xarray/core/resample.py:403, in DatasetResample.reduce(self, func, dim, axis, keep_attrs, keepdims, shortcut, **kwargs)
#     368 def reduce(
#     369     self,
#     370     func: Callable[..., Any],
#    (...)
#     377     **kwargs: Any,
#     378 ) -> Dataset:
#     379     """Reduce the items in this group by applying `func` along the
#     380     pre-defined resampling dimension.
#     381
#    (...)
#     401         removed.
#     402     """
# --> 403     return super().reduce(
#     404         func=func,
#     405         dim=dim,
#     406         axis=axis,
#     407         keep_attrs=keep_attrs,
#     408         keepdims=keepdims,
#     409         shortcut=shortcut,
#     410         **kwargs,
#     411     )
#
# File ~/anaconda3/envs/kite/lib/python3.9/site-packages/xarray/core/groupby.py:1354, in DatasetGroupByBase.reduce(self, func, dim, axis, keep_attrs, keepdims, shortcut, **kwargs)
#    1343     return ds.reduce(
#    1344         func=func,
#    1345         dim=dim,
#    (...)
#    1349         **kwargs,
#    1350     )
#    1352 check_reduce_dims(dim, self.dims)
# -> 1354 return self.map(reduce_dataset)
#
# File ~/anaconda3/envs/kite/lib/python3.9/site-packages/xarray/core/resample.py:339, in DatasetResample.map(self, func, args, shortcut, **kwargs)
#     337 # ignore shortcut if set (for now)
#     338 applied = (func(ds, *args, **kwargs) for ds in self._iter_grouped())
# --> 339 combined = self._combine(applied)
#     341 # If the aggregation function didn't drop the original resampling
#     342 # dimension, then we need to do so before we can rename the proxy
#     343 # dimension we used.
#     344 if self._dim in combined.coords:
#
# File ~/anaconda3/envs/kite/lib/python3.9/site-packages/xarray/core/groupby.py:1292, in DatasetGroupByBase._combine(self, applied)
#    1290     indexes = {k: index for k in index_vars}
#    1291     combined = combined._overwrite_indexes(indexes, index_vars)
# -> 1292 combined = self._maybe_restore_empty_groups(combined)
#    1293 combined = self._maybe_unstack(combined)
#    1294 return combined
#
# File ~/anaconda3/envs/kite/lib/python3.9/site-packages/xarray/core/groupby.py:639, in GroupBy._maybe_restore_empty_groups(self, combined)
#     637 if self._full_index is not None and self._group.name in combined.dims:
#     638     indexers = {self._group.name: self._full_index}
# --> 639     combined = combined.reindex(**indexers)
#     640 return combined
#
# File ~/anaconda3/envs/kite/lib/python3.9/site-packages/xarray/core/dataset.py:3122, in Dataset.reindex(self, indexers, method, tolerance, copy, fill_value, **indexers_kwargs)
#    2924 """Conform this object onto a new set of indexes, filling in
#    2925 missing values with ``fill_value``. The default fill value is NaN.
#    2926
#    (...)
#    3119
#    3120 """
#    3121 indexers = utils.either_dict_or_kwargs(indexers, indexers_kwargs, "reindex")
# -> 3122 return alignment.reindex(
#    3123     self,
#    3124     indexers=indexers,
#    3125     method=method,
#    3126     tolerance=tolerance,
#    3127     copy=copy,
#    3128     fill_value=fill_value,
#    3129 )
#
# File ~/anaconda3/envs/kite/lib/python3.9/site-packages/xarray/core/alignment.py:888, in reindex(obj, indexers, method, tolerance, copy, fill_value, sparse, exclude_vars)
#     869 # TODO: (benbovy - explicit indexes): uncomment?
#     870 # --> from reindex docstrings: "any mis-matched dimension is simply ignored"
#     871 # bad_keys = [k for k in indexers if k not in obj._indexes and k not in obj.dims]
#    (...)
#     875 #         "or unindexed dimension in the object to reindex"
#     876 #     )
#     878 aligner = Aligner(
#     879     (obj,),
#     880     indexes=indexers,
#    (...)
#     886     exclude_vars=exclude_vars,
#     887 )
# --> 888 aligner.align()
#     889 return aligner.results[0]
#
# File ~/anaconda3/envs/kite/lib/python3.9/site-packages/xarray/core/alignment.py:565, in Aligner.align(self)
#     563     self.override_indexes()
#     564 else:
# --> 565     self.reindex_all()
#
# File ~/anaconda3/envs/kite/lib/python3.9/site-packages/xarray/core/alignment.py:542, in Aligner.reindex_all(self)
#     541 def reindex_all(self) -> None:
# --> 542     self.results = tuple(
#     543         self._reindex_one(obj, matching_indexes)
#     544         for obj, matching_indexes in zip(
#     545             self.objects, self.objects_matching_indexes
#     546         )
#     547     )
#
# File ~/anaconda3/envs/kite/lib/python3.9/site-packages/xarray/core/alignment.py:543, in <genexpr>(.0)
#     541 def reindex_all(self) -> None:
#     542     self.results = tuple(
# --> 543         self._reindex_one(obj, matching_indexes)
#     544         for obj, matching_indexes in zip(
#     545             self.objects, self.objects_matching_indexes
#     546         )
#     547     )
#
# File ~/anaconda3/envs/kite/lib/python3.9/site-packages/xarray/core/alignment.py:529, in Aligner._reindex_one(self, obj, matching_indexes)
#     526 new_indexes, new_variables = self._get_indexes_and_vars(obj, matching_indexes)
#     527 dim_pos_indexers = self._get_dim_pos_indexers(matching_indexes)
# --> 529 new_obj = obj._reindex_callback(
#     530     self,
#     531     dim_pos_indexers,
#     532     new_variables,
#     533     new_indexes,
#     534     self.fill_value,
#     535     self.exclude_dims,
#     536     self.exclude_vars,
#     537 )
#     538 new_obj.encoding = obj.encoding
#     539 return new_obj
#
# File ~/anaconda3/envs/kite/lib/python3.9/site-packages/xarray/core/dataset.py:2827, in Dataset._reindex_callback(self, aligner, dim_pos_indexers, variables, indexes, fill_value, exclude_dims, exclude_vars)
#    2825         reindexed = self._overwrite_indexes(new_indexes, new_variables)
#    2826     else:
# -> 2827         reindexed = self.copy(deep=aligner.copy)
#    2828 else:
#    2829     to_reindex = {
#    2830         k: v
#    2831         for k, v in self.variables.items()
#    2832         if k not in variables and k not in exclude_vars
#    2833     }
#
# File ~/anaconda3/envs/kite/lib/python3.9/site-packages/xarray/core/dataset.py:1229, in Dataset.copy(self, deep, data)
#    1130 def copy(
#    1131     self: T_Dataset, deep: bool = False, data: Mapping[Any, ArrayLike] | None = None
#    1132 ) -> T_Dataset:
#    1133     """Returns a copy of this dataset.
#    1134
#    1135     If `deep=True`, a deep copy is made of each of the component variables.
#    (...)
#    1227     pandas.DataFrame.copy
#    1228     """
# -> 1229     return self._copy(deep=deep, data=data)
#
# File ~/anaconda3/envs/kite/lib/python3.9/site-packages/xarray/core/dataset.py:1265, in Dataset._copy(self, deep, data, memo)
#    1263         variables[k] = index_vars[k]
#    1264     else:
# -> 1265         variables[k] = v._copy(deep=deep, data=data.get(k), memo=memo)
#    1267 attrs = copy.deepcopy(self._attrs, memo) if deep else copy.copy(self._attrs)
#    1268 encoding = (
#    1269     copy.deepcopy(self._encoding, memo) if deep else copy.copy(self._encoding)
#    1270 )
#
# File ~/anaconda3/envs/kite/lib/python3.9/site-packages/xarray/core/variable.py:1048, in Variable._copy(self, deep, data, memo)
#    1045         ndata = indexing.MemoryCachedArray(ndata.array)
#    1047     if deep:
# -> 1048         ndata = copy.deepcopy(ndata, memo)
#    1050 else:
#    1051     ndata = as_compatible_data(data)
#
# File ~/anaconda3/envs/kite/lib/python3.9/copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# KeyboardInterrupt:

# %%
for i in range (len(file)):
    file[i] = xr.concat(concat[i],'hour')
    file[i]['hour'] = hour

# %%
with ProgressBar():
    concat.to_netcdf('/data1/user/gychoi/Data/simple_tfs/era_lst.nc')
